# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\aryan\miniconda3\lib\site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: seaborn in c:\users\aryan\miniconda3\lib\site-packages (from -r requirements.txt (line 2)) (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\aryan\miniconda3\lib\site-packages (from -r requirements.txt (line 3)) (3.9.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\aryan\miniconda3\lib\site-packages (from seaborn->-r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aryan\miniconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aryan\miniconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aryan\miniconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aryan\miniconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aryan\miniconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\aryan\miniconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aryan\miniconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aryan\miniconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aryan\miniconda3\lib\site-packages (from pandas>=1.2->seaborn->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aryan\miniconda3\lib\site-packages (from pandas>=1.2->seaborn->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\aryan\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 3)) (1.16.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
"""
Functions written for ease of usage of the model.
"""

def get_features_targets(df: pd.DataFrame, 
                         feature_names: list[str], 
                         target_names: list[str]) -> tuple[pd.DataFrame, pd.DataFrame]:
    df_feature = pd.DataFrame(df[feature_names[:]])
    df_target = pd.DataFrame(df[target_names[:]])
    return df_feature, df_target

def plot_data(df: pd.DataFrame, 
              feature: str, 
              target: str):
    sns.set()
    feature = pd.DataFrame(df[feature])
    target = pd.DataFrame(df[target])
    plt.scatter(feature, target)

# Finds xy correlation constant
def calc_correlation(df: pd.DataFrame,
                     feature: str,
                     target: str):
    f = df[feature].to_numpy()
    t = df[target].to_numpy()
    coef = np.corrcoef(f, t)[0][1]
    if np.isnan(coef):
        return 0
    return coef

def get_numpy_features(df: pd.DataFrame,
                       feature_names: list[str],
                       target_names: list[str]):
    f, t = get_features_targets(df, feature_names, target_names)
    for feature in f.iterrows():
        
    
    for feat
    return t.to_numpy()

# %%
"""
Getting Data from data.csv.
"""

try:
    df: pd.DataFrame = pd.read_csv("../data/data.csv")
    if (len(set(df.count())) != 1):
        raise Exception("Datapoints differ across columns")
except Exception as e:
    print(f"Caught: {e}")

# print(df)

# Sanity check: stops program if the number of datapoints differ across columns


# Independant Variable
VAR_Y = 'YEAR'
VAR_C = 'CROP_YIELD_BPA'
VAR_CU = 'CROP_YIELD_USA_BPA'

# Dependant Variables
dep = {
    VAR_TEMP : 'TEMP_F',
    VAR_RAIN : 'RAINFALL_IN',
    VAR_WIND : 'WINDSPEED_MPH',
    VAR_SNOW : 'SNOWFALL_IN',
    VAR_PEST : 'PESTICIDE_M_TON',
    VAR_GDP : 'GDP_$',
    VAR_FERT : 'FERTILISER_M_TON',
}

df_features, df_target = get_features_targets(df, 
                                              [dep[var] for var in dep.keys()], 
                                              [VAR_CU])

# print("Features: ", df_features["TEMP_F"])
# print("Target: ", df_target)
# Out:
# Caught:Datapoints differ across columns

# %%
f = np.array([])
print(f)
# Out:
# []

# %%
"""
Relationship between each dependant and independant variable

"""
plt.figure(figsize=(30, 15))

i = 1
for var in dep:
    plt.subplot(2, 4, i)
    plt.xlabel(var)
    plt.ylabel("CY")
    r = calc_correlation(df, dep[var], VAR_CU)
    plt.title(f"r = {round(r, 3)}")
    plot_data(df, dep[var], VAR_C)
    i += 1

plt.savefig("../data/figures/correlation.png")
# plot_data(df, dep[VAR_PEST], VAR_C)

# %%
chosen_dep = {
    VAR_SNOW: 'SNOWFALL_IN',
    VAR_PEST: 'PESTICIDE_M_TON',
    VAR_GDP: 'GDP_$'
}

plt.figure(figsize=(15, 5))

i = 1
for var in chosen_dep:
    plt.subplot(1, 3, i)
    plt.xlabel(var)
    plt.ylabel("CY")
    r = calc_correlation(df, dep[var], VAR_CU)
    plt.title(f"r = {round(r, 3)}")
    plot_data(df, dep[var], VAR_C)
    i += 1

plt.savefig("../data/figures/chosendep.png")

# %%
"""
Linear Regression
"""

from regression_functions import MVF

# Data transformation

f, t = get_numpy_features(df, [chosen_dep[var] for var in chosen_dep.keys()], [VAR_CU])
print(f)
print(t)
# Out:
# [[4.6800e+01 1.8100e+00 2.3889e+04]
#  [3.8500e+01 1.7900e+00 2.4342e+04]
#  [9.8700e+01 1.8200e+00 2.5419e+04]
#  [3.8800e+01 1.8400e+00 2.6387e+04]
#  [8.5200e+01 1.8900e+00 2.7695e+04]
#  [8.5700e+01 1.9600e+00 2.8691e+04]
#  [6.0300e+01 2.0200e+00 2.9968e+04]
#  [6.1600e+01 2.0900e+00 3.1459e+04]
#  [3.2200e+01 2.1300e+00 3.2854e+04]
#  [5.0300e+01 2.1600e+00 3.4515e+04]
#  [6.4000e+01 2.1800e+00 3.6330e+04]
#  [7.3500e+01 2.1800e+00 3.7134e+04]
#  [2.2300e+01 2.2100e+00 3.7998e+04]
#  [7.7500e+01 2.3100e+00 3.9490e+04]
#  [2.7900e+01 2.4500e+00 4.1725e+04]
#  [4.6200e+01 2.5300e+00 4.4123e+04]
#  [4.4400e+01 2.5100e+00 4.6302e+04]
#  [7.3500e+01 2.7700e+00 4.8050e+04]
#  [4.8300e+01 2.8300e+00 4.8570e+04]
#  [3.6400e+01 2.7300e+00 4.7195e+04]
#  [6.8400e+01 3.0300e+00 4.8651e+04]
#  [2.4800e+01 3.0500e+00 5.0066e+04]
#  [6.9900e+01 3.2000e+00 5.1784e+04]
#  [3.5400e+01 3.2700e+00 5.3410e+04]
#  [1.5400e+01 3.2800e+00 5.5304e+04]
#  [3.4300e+01 3.3200e+00 5.7040e+04]
#  [5.1400e+01 3.4400e+00 5.8207e+04]
#  [4.3500e+01 3.3600e+00 6.0322e+04]
#  [4.6300e+01 3.4000e+00 6.3201e+04]
#  [4.3900e+01 3.4800e+00 6.5548e+04]
#  [2.7900e+01 3.4500e+00 6.4317e+04]
#  [3.8800e+01 3.5700e+00 7.1056e+04]
#  [8.7500e+01 3.6900e+00 7.7247e+04]]
# [[114.84]
#  [116.97]
#  [119.1 ]
#  [113.5 ]
#  [127.1 ]
#  [126.7 ]
#  [134.4 ]
#  [133.8 ]
#  [136.9 ]
#  [138.2 ]
#  [129.3 ]
#  [142.4 ]
#  [160.3 ]
#  [147.9 ]
#  [149.1 ]
#  [150.7 ]
#  [153.3 ]
#  [164.4 ]
#  [152.6 ]
#  [146.8 ]
#  [123.1 ]
#  [158.1 ]
#  [171.  ]
#  [168.4 ]
#  [174.6 ]
#  [176.6 ]
#  [176.4 ]
#  [167.5 ]
#  [171.4 ]
#  [176.7 ]
#  [173.4 ]
#  [177.3 ]
#  [183.1 ]]
